# %%
#Configure Box
d = {"key": "value", "number": 42, "list": [1, 2, 3]}

# %%
d['key']
# Out:
# 'value'

# %%
from box import ConfigBox

# %%
d1 = ConfigBox({"key": "value", "number": 42, "list": [1, 2, 3]})
d1.key
# Out:
# 'value'

# %%
d1.number
# Out:
# 42

# %%
d1.list
# Out:
# <bound method ConfigBox.list of ConfigBox({'key': 'value', 'number': 42, 'list': [1, 2, 3]})>

# %%
# ensure annotations are working
def get_prodict(x:int,y:int)->int:
    return x*y

# %%
get_prodict(10,32)
# Out:
# 320

# %%
get_prodict(2,'3')
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_prodict(x:int,y:int)->int:
    return x*y

# %%
get_prodict(2,3)
# Out:
# 6

# %%
get_prodict(2,'3')
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_prodict(2,'3')
#
# File c:\Users\viveksharma\OneDrive\Desktop\mlops\Kideny-Disease-Classification_PROJECT\kidney\Lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_prodict at 0x000002132AB1A660> does not match annotation type <class 'int'>

# %% [markdown]
# ## download data from google drive

# %%
pip install gdown
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/19NiXTXgVAlrlWZTA63-VVMbL9JP6E9cI/view?usp=sharing"

# %%
url.split('/')
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '19NiXTXgVAlrlWZTA63-VVMbL9JP6E9cI',
#  'view?usp=sharing']

# %%
file_id =url.split('/')[-2]

# %%
prefix = "https://drive.google.com/uc?export=download&id="
gdown.download(prefix+file_id, "kidney_CT_scan_image.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=19NiXTXgVAlrlWZTA63-VVMbL9JP6E9cI
# From (redirected): https://drive.google.com/uc?export=download&id=19NiXTXgVAlrlWZTA63-VVMbL9JP6E9cI&confirm=t&uuid=ac299309-f2ff-4a72-a40a-7af23f163452
# To: c:\Users\viveksharma\OneDrive\Desktop\mlops\Kideny-Disease-Classification_PROJECT\research\kidney_CT_scan_image.zip
# 100%|██████████| 1.63G/1.63G [07:18<00:00, 3.72MB/s]
# 'kidney_CT_scan_image.zip'
